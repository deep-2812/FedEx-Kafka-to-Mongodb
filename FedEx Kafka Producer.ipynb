# %% [markdown]
# # Setup

# %%
# pip install python-dotenv

# %%
import random
import time
from datetime import datetime, timezone
from confluent_kafka import SerializingProducer
from confluent_kafka.serialization import StringSerializer
from confluent_kafka.schema_registry import SchemaRegistryClient
from confluent_kafka.schema_registry.avro import AvroSerializer
from dotenv import dotenv_values

# %% [markdown]
# ### Kafka Config

# %%
imp_keys = dotenv_values(".env")

# %%
#Define Kafka Config
kakfa_config = {
    'bootstrap.servers': imp_keys['BOOTSTRAP_SERVER'],
    'sasl.mechanisms': 'PLAIN',
    'security.protocol': 'SASL_SSL',
    'sasl.username': imp_keys['SASL_USERNAME'],
    'sasl.password': imp_keys['SASL_PASSWORD']
}

# %%
#Define Schema Registry Config
schema_registry_client = SchemaRegistryClient({
    'url' : imp_keys['SCHEMA_REGISTRY_URL'],
    'basic.auth.user.info' : f"{imp_keys['SCHEMA_REGISTRY_API_KEY']}:{imp_keys['SCHEMA_REGISTRY_API_SECRET']}"
})

# %%
# Fetch the latest Avro schema for the value
subject_name = 'FedEx-value'
schema_str = schema_registry_client.get_latest_version(subject_name).schema.schema_str
print("Schema from Registery---")
print(schema_str)
print("=====================")
# Out:
# Schema from Registery---
# {"type":"record","name":"fedEx","namespace":"com.assignment.fedex","fields":[{"name":"shipment_id","type":"string"},{"name":"origin","type":"string"},{"name":"destination","type":"string"},{"name":"status","type":"string"},{"name":"timestamp","type":{"type":"long","logicalType":"timestamp-millis"}}]}
# =====================

# %%
#Create Avro serializer for the value
key_serializer = StringSerializer('utf_8')
value_serializer = AvroSerializer(schema_registry_client, schema_str)

# %%
#Creating Delivery Report
def delivery_report(err, msg):
    """
    Reports the failure or success of a message delivery.

    Args:
        err (KafkaError): The error that occurred on None on success.

        msg (Message): The message that was produced or failed.

    Note:
        In the delivery report callback the Message.key() and Message.value()
        will be the binary format as encoded by any configured Serializers and
        not the same object that was passed to produce().
        If you wish to pass the original object(s) for key and value to delivery
        report callback we recommend a bound callback or lambda where you pass
        the objects along.

    """
    if err is not None:
        print(f"Delivery failed for User record {msg.key()}: {err}")
        return
    print(f'User record {msg.key()} successfully produced to {msg.topic()} [{msg.partition()}] at offset {msg.offset()}')
    print("=====================")

# %% [markdown]
# # Producer

# %%
producer = SerializingProducer({
    **kakfa_config, 
    'key.serializer' : key_serializer,
    'value.serializer' : value_serializer
})

# %%
print(kakfa_config['sasl.password'])
# Out:
# gJ8V9FS5W3ghxikA7kJwzqe/6zCPaU5iVRnQWBAlyubr6GKLSuIvbj4owwXMLoTf

# %%
origin = ['Mumbai, IN', 'Delhi, IN', 'Bangalore, IN', 'Chennai, IN', 'Kolkata, IN']
destination = ["Los Angeles, CA"
               ,"Dallas, TX"
               , "Philadelphia, PA"
               , "Phoenix, AZ"
               ,"San Diego, CA"
               ,"San Antonio, TX"
               ,"Portland, OR"
               ,"Detroit, MI"
               ,"Charlotte, NC"
               ,"Minneapolis, MN"]
status = ['Shipped', 'In Transit', 'Delivered', 'Returned']
timestamp = datetime.now(timezone.utc)

# %%
print(timestamp)
# Out:
# 2025-02-04 07:56:54.528040+00:00

# %%
i = 0
while True:
    i += 1
    data = {
        "shipment_id": f"SH00{i}",
        "origin": random.choice(origin),
        "destination": random.choice(destination),
        "status": random.choice(status),
        "timestamp": timestamp
    }
    print(data)
    producer.produce(
        topic = 'FedEx', 
        key = str(data["shipment_id"]),
        value = data,
        on_delivery = delivery_report
    )
    producer.flush()
    time.sleep(2)
    # if i == 10:
    #     break
# Out:
# {'shipment_id': 'SH001', 'origin': 'Mumbai, IN', 'destination': 'Minneapolis, MN', 'status': 'Delivered', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# %6|1738655814.806|GETSUBSCRIPTIONS|rdkafka#producer-4| [thrd:main]: Telemetry client instance id changed from AAAAAAAAAAAAAAAAAAAAAA to iUmQohexTMWATrr9hBXCjw
# User record b'SH001' successfully produced to FedEx [1] at offset 9
# =====================
# {'shipment_id': 'SH002', 'origin': 'Kolkata, IN', 'destination': 'Philadelphia, PA', 'status': 'Shipped', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH002' successfully produced to FedEx [1] at offset 10
# =====================
# {'shipment_id': 'SH003', 'origin': 'Delhi, IN', 'destination': 'San Diego, CA', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH003' successfully produced to FedEx [1] at offset 11
# =====================
# {'shipment_id': 'SH004', 'origin': 'Chennai, IN', 'destination': 'Los Angeles, CA', 'status': 'In Transit', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH004' successfully produced to FedEx [0] at offset 6
# =====================
# {'shipment_id': 'SH005', 'origin': 'Bangalore, IN', 'destination': 'Charlotte, NC', 'status': 'Shipped', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH005' successfully produced to FedEx [0] at offset 7
# =====================
# {'shipment_id': 'SH006', 'origin': 'Delhi, IN', 'destination': 'Phoenix, AZ', 'status': 'Delivered', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH006' successfully produced to FedEx [0] at offset 8
# =====================
# {'shipment_id': 'SH007', 'origin': 'Bangalore, IN', 'destination': 'Detroit, MI', 'status': 'Shipped', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH007' successfully produced to FedEx [0] at offset 9
# =====================
# {'shipment_id': 'SH008', 'origin': 'Mumbai, IN', 'destination': 'San Antonio, TX', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH008' successfully produced to FedEx [1] at offset 12
# =====================
# {'shipment_id': 'SH009', 'origin': 'Mumbai, IN', 'destination': 'Portland, OR', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH009' successfully produced to FedEx [1] at offset 13
# =====================
# {'shipment_id': 'SH0010', 'origin': 'Kolkata, IN', 'destination': 'San Antonio, TX', 'status': 'In Transit', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0010' successfully produced to FedEx [1] at offset 14
# =====================
# {'shipment_id': 'SH0011', 'origin': 'Chennai, IN', 'destination': 'Detroit, MI', 'status': 'Delivered', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0011' successfully produced to FedEx [1] at offset 15
# =====================
# {'shipment_id': 'SH0012', 'origin': 'Bangalore, IN', 'destination': 'Minneapolis, MN', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0012' successfully produced to FedEx [1] at offset 16
# =====================
# {'shipment_id': 'SH0013', 'origin': 'Kolkata, IN', 'destination': 'Los Angeles, CA', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0013' successfully produced to FedEx [1] at offset 17
# =====================
# {'shipment_id': 'SH0014', 'origin': 'Mumbai, IN', 'destination': 'San Diego, CA', 'status': 'Shipped', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0014' successfully produced to FedEx [0] at offset 10
# =====================
# {'shipment_id': 'SH0015', 'origin': 'Chennai, IN', 'destination': 'Portland, OR', 'status': 'Shipped', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0015' successfully produced to FedEx [0] at offset 11
# =====================
# {'shipment_id': 'SH0016', 'origin': 'Mumbai, IN', 'destination': 'San Diego, CA', 'status': 'Shipped', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0016' successfully produced to FedEx [0] at offset 12
# =====================
# {'shipment_id': 'SH0017', 'origin': 'Mumbai, IN', 'destination': 'San Diego, CA', 'status': 'Shipped', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0017' successfully produced to FedEx [0] at offset 13
# =====================
# {'shipment_id': 'SH0018', 'origin': 'Kolkata, IN', 'destination': 'Philadelphia, PA', 'status': 'Shipped', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0018' successfully produced to FedEx [1] at offset 18
# =====================
# {'shipment_id': 'SH0019', 'origin': 'Mumbai, IN', 'destination': 'Dallas, TX', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0019' successfully produced to FedEx [1] at offset 19
# =====================
# {'shipment_id': 'SH0020', 'origin': 'Mumbai, IN', 'destination': 'Minneapolis, MN', 'status': 'Shipped', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0020' successfully produced to FedEx [0] at offset 14
# =====================
# {'shipment_id': 'SH0021', 'origin': 'Delhi, IN', 'destination': 'Charlotte, NC', 'status': 'Delivered', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0021' successfully produced to FedEx [0] at offset 15
# =====================
# {'shipment_id': 'SH0022', 'origin': 'Delhi, IN', 'destination': 'Los Angeles, CA', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0022' successfully produced to FedEx [0] at offset 16
# =====================
# {'shipment_id': 'SH0023', 'origin': 'Delhi, IN', 'destination': 'San Diego, CA', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0023' successfully produced to FedEx [0] at offset 17
# =====================
# {'shipment_id': 'SH0024', 'origin': 'Kolkata, IN', 'destination': 'San Antonio, TX', 'status': 'Shipped', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0024' successfully produced to FedEx [1] at offset 20
# =====================
# {'shipment_id': 'SH0025', 'origin': 'Delhi, IN', 'destination': 'Minneapolis, MN', 'status': 'Delivered', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0025' successfully produced to FedEx [1] at offset 21
# =====================
# {'shipment_id': 'SH0026', 'origin': 'Kolkata, IN', 'destination': 'Los Angeles, CA', 'status': 'Delivered', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0026' successfully produced to FedEx [1] at offset 22
# =====================
# {'shipment_id': 'SH0027', 'origin': 'Delhi, IN', 'destination': 'Los Angeles, CA', 'status': 'In Transit', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0027' successfully produced to FedEx [1] at offset 23
# =====================
# {'shipment_id': 'SH0028', 'origin': 'Bangalore, IN', 'destination': 'Phoenix, AZ', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0028' successfully produced to FedEx [0] at offset 18
# =====================
# {'shipment_id': 'SH0029', 'origin': 'Bangalore, IN', 'destination': 'San Diego, CA', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0029' successfully produced to FedEx [0] at offset 19
# =====================
# {'shipment_id': 'SH0030', 'origin': 'Delhi, IN', 'destination': 'San Antonio, TX', 'status': 'Shipped', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0030' successfully produced to FedEx [1] at offset 24
# =====================
# {'shipment_id': 'SH0031', 'origin': 'Kolkata, IN', 'destination': 'San Diego, CA', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0031' successfully produced to FedEx [1] at offset 25
# =====================
# {'shipment_id': 'SH0032', 'origin': 'Delhi, IN', 'destination': 'San Antonio, TX', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0032' successfully produced to FedEx [1] at offset 26
# =====================
# {'shipment_id': 'SH0033', 'origin': 'Mumbai, IN', 'destination': 'Phoenix, AZ', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0033' successfully produced to FedEx [1] at offset 27
# =====================
# {'shipment_id': 'SH0034', 'origin': 'Delhi, IN', 'destination': 'Phoenix, AZ', 'status': 'In Transit', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0034' successfully produced to FedEx [0] at offset 20
# =====================
# {'shipment_id': 'SH0035', 'origin': 'Kolkata, IN', 'destination': 'Phoenix, AZ', 'status': 'In Transit', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0035' successfully produced to FedEx [0] at offset 21
# =====================
# {'shipment_id': 'SH0036', 'origin': 'Mumbai, IN', 'destination': 'Minneapolis, MN', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0036' successfully produced to FedEx [0] at offset 22
# =====================
# {'shipment_id': 'SH0037', 'origin': 'Delhi, IN', 'destination': 'Minneapolis, MN', 'status': 'Delivered', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0037' successfully produced to FedEx [0] at offset 23
# =====================
# {'shipment_id': 'SH0038', 'origin': 'Mumbai, IN', 'destination': 'San Diego, CA', 'status': 'Delivered', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0038' successfully produced to FedEx [1] at offset 28
# =====================
# {'shipment_id': 'SH0039', 'origin': 'Mumbai, IN', 'destination': 'Portland, OR', 'status': 'Delivered', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0039' successfully produced to FedEx [1] at offset 29
# =====================
# {'shipment_id': 'SH0040', 'origin': 'Kolkata, IN', 'destination': 'Detroit, MI', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0040' successfully produced to FedEx [0] at offset 24
# =====================
# {'shipment_id': 'SH0041', 'origin': 'Bangalore, IN', 'destination': 'Minneapolis, MN', 'status': 'Delivered', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0041' successfully produced to FedEx [0] at offset 25
# =====================
# {'shipment_id': 'SH0042', 'origin': 'Kolkata, IN', 'destination': 'San Diego, CA', 'status': 'In Transit', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0042' successfully produced to FedEx [0] at offset 26
# =====================
# {'shipment_id': 'SH0043', 'origin': 'Kolkata, IN', 'destination': 'Minneapolis, MN', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0043' successfully produced to FedEx [0] at offset 27
# =====================
# {'shipment_id': 'SH0044', 'origin': 'Mumbai, IN', 'destination': 'Portland, OR', 'status': 'In Transit', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0044' successfully produced to FedEx [1] at offset 30
# =====================
# {'shipment_id': 'SH0045', 'origin': 'Mumbai, IN', 'destination': 'Portland, OR', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0045' successfully produced to FedEx [1] at offset 31
# =====================
# {'shipment_id': 'SH0046', 'origin': 'Kolkata, IN', 'destination': 'Charlotte, NC', 'status': 'In Transit', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0046' successfully produced to FedEx [1] at offset 32
# =====================
# {'shipment_id': 'SH0047', 'origin': 'Bangalore, IN', 'destination': 'San Antonio, TX', 'status': 'Delivered', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0047' successfully produced to FedEx [1] at offset 33
# =====================
# {'shipment_id': 'SH0048', 'origin': 'Kolkata, IN', 'destination': 'Dallas, TX', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0048' successfully produced to FedEx [0] at offset 28
# =====================
# {'shipment_id': 'SH0049', 'origin': 'Bangalore, IN', 'destination': 'San Diego, CA', 'status': 'Delivered', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0049' successfully produced to FedEx [0] at offset 29
# =====================
# {'shipment_id': 'SH0050', 'origin': 'Kolkata, IN', 'destination': 'Detroit, MI', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0050' successfully produced to FedEx [1] at offset 34
# =====================
# {'shipment_id': 'SH0051', 'origin': 'Mumbai, IN', 'destination': 'Detroit, MI', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0051' successfully produced to FedEx [1] at offset 35
# =====================
# {'shipment_id': 'SH0052', 'origin': 'Mumbai, IN', 'destination': 'Detroit, MI', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0052' successfully produced to FedEx [1] at offset 36
# =====================
# {'shipment_id': 'SH0053', 'origin': 'Chennai, IN', 'destination': 'Philadelphia, PA', 'status': 'Delivered', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0053' successfully produced to FedEx [1] at offset 37
# =====================
# {'shipment_id': 'SH0054', 'origin': 'Bangalore, IN', 'destination': 'San Antonio, TX', 'status': 'Shipped', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0054' successfully produced to FedEx [0] at offset 30
# =====================
# {'shipment_id': 'SH0055', 'origin': 'Mumbai, IN', 'destination': 'Minneapolis, MN', 'status': 'Shipped', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0055' successfully produced to FedEx [0] at offset 31
# =====================
# {'shipment_id': 'SH0056', 'origin': 'Delhi, IN', 'destination': 'Philadelphia, PA', 'status': 'Delivered', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0056' successfully produced to FedEx [0] at offset 32
# =====================
# {'shipment_id': 'SH0057', 'origin': 'Kolkata, IN', 'destination': 'Detroit, MI', 'status': 'In Transit', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0057' successfully produced to FedEx [0] at offset 33
# =====================
# {'shipment_id': 'SH0058', 'origin': 'Bangalore, IN', 'destination': 'Charlotte, NC', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0058' successfully produced to FedEx [1] at offset 38
# =====================
# {'shipment_id': 'SH0059', 'origin': 'Bangalore, IN', 'destination': 'Minneapolis, MN', 'status': 'Delivered', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0059' successfully produced to FedEx [1] at offset 39
# =====================
# {'shipment_id': 'SH0060', 'origin': 'Delhi, IN', 'destination': 'Los Angeles, CA', 'status': 'Shipped', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0060' successfully produced to FedEx [0] at offset 34
# =====================
# {'shipment_id': 'SH0061', 'origin': 'Bangalore, IN', 'destination': 'San Antonio, TX', 'status': 'In Transit', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0061' successfully produced to FedEx [0] at offset 35
# =====================
# {'shipment_id': 'SH0062', 'origin': 'Bangalore, IN', 'destination': 'Minneapolis, MN', 'status': 'In Transit', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0062' successfully produced to FedEx [0] at offset 36
# =====================
# {'shipment_id': 'SH0063', 'origin': 'Delhi, IN', 'destination': 'Phoenix, AZ', 'status': 'In Transit', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0063' successfully produced to FedEx [0] at offset 37
# =====================
# {'shipment_id': 'SH0064', 'origin': 'Delhi, IN', 'destination': 'San Diego, CA', 'status': 'In Transit', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0064' successfully produced to FedEx [1] at offset 40
# =====================
# {'shipment_id': 'SH0065', 'origin': 'Mumbai, IN', 'destination': 'Charlotte, NC', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0065' successfully produced to FedEx [1] at offset 41
# =====================
# {'shipment_id': 'SH0066', 'origin': 'Chennai, IN', 'destination': 'Phoenix, AZ', 'status': 'Delivered', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0066' successfully produced to FedEx [1] at offset 42
# =====================
# {'shipment_id': 'SH0067', 'origin': 'Chennai, IN', 'destination': 'Phoenix, AZ', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0067' successfully produced to FedEx [1] at offset 43
# =====================
# {'shipment_id': 'SH0068', 'origin': 'Kolkata, IN', 'destination': 'San Antonio, TX', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0068' successfully produced to FedEx [0] at offset 38
# =====================
# {'shipment_id': 'SH0069', 'origin': 'Delhi, IN', 'destination': 'Phoenix, AZ', 'status': 'Shipped', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0069' successfully produced to FedEx [0] at offset 39
# =====================
# {'shipment_id': 'SH0070', 'origin': 'Mumbai, IN', 'destination': 'San Diego, CA', 'status': 'Delivered', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0070' successfully produced to FedEx [1] at offset 44
# =====================
# {'shipment_id': 'SH0071', 'origin': 'Bangalore, IN', 'destination': 'San Antonio, TX', 'status': 'Shipped', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0071' successfully produced to FedEx [1] at offset 45
# =====================
# {'shipment_id': 'SH0072', 'origin': 'Chennai, IN', 'destination': 'Detroit, MI', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0072' successfully produced to FedEx [1] at offset 46
# =====================
# {'shipment_id': 'SH0073', 'origin': 'Bangalore, IN', 'destination': 'Los Angeles, CA', 'status': 'In Transit', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0073' successfully produced to FedEx [1] at offset 47
# =====================
# {'shipment_id': 'SH0074', 'origin': 'Delhi, IN', 'destination': 'Minneapolis, MN', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0074' successfully produced to FedEx [0] at offset 40
# =====================
# {'shipment_id': 'SH0075', 'origin': 'Delhi, IN', 'destination': 'San Antonio, TX', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0075' successfully produced to FedEx [0] at offset 41
# =====================
# {'shipment_id': 'SH0076', 'origin': 'Kolkata, IN', 'destination': 'San Diego, CA', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0076' successfully produced to FedEx [0] at offset 42
# =====================
# {'shipment_id': 'SH0077', 'origin': 'Kolkata, IN', 'destination': 'Dallas, TX', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0077' successfully produced to FedEx [0] at offset 43
# =====================
# {'shipment_id': 'SH0078', 'origin': 'Bangalore, IN', 'destination': 'San Antonio, TX', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0078' successfully produced to FedEx [1] at offset 48
# =====================
# {'shipment_id': 'SH0079', 'origin': 'Chennai, IN', 'destination': 'Minneapolis, MN', 'status': 'In Transit', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0079' successfully produced to FedEx [1] at offset 49
# =====================
# {'shipment_id': 'SH0080', 'origin': 'Kolkata, IN', 'destination': 'Detroit, MI', 'status': 'Delivered', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0080' successfully produced to FedEx [0] at offset 44
# =====================
# {'shipment_id': 'SH0081', 'origin': 'Chennai, IN', 'destination': 'Charlotte, NC', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0081' successfully produced to FedEx [0] at offset 45
# =====================
# {'shipment_id': 'SH0082', 'origin': 'Delhi, IN', 'destination': 'Dallas, TX', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0082' successfully produced to FedEx [0] at offset 46
# =====================
# {'shipment_id': 'SH0083', 'origin': 'Mumbai, IN', 'destination': 'San Antonio, TX', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0083' successfully produced to FedEx [0] at offset 47
# =====================
# {'shipment_id': 'SH0084', 'origin': 'Delhi, IN', 'destination': 'Los Angeles, CA', 'status': 'Shipped', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0084' successfully produced to FedEx [1] at offset 50
# =====================
# {'shipment_id': 'SH0085', 'origin': 'Delhi, IN', 'destination': 'Portland, OR', 'status': 'In Transit', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0085' successfully produced to FedEx [1] at offset 51
# =====================
# {'shipment_id': 'SH0086', 'origin': 'Mumbai, IN', 'destination': 'Minneapolis, MN', 'status': 'Shipped', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0086' successfully produced to FedEx [1] at offset 52
# =====================
# {'shipment_id': 'SH0087', 'origin': 'Bangalore, IN', 'destination': 'Los Angeles, CA', 'status': 'In Transit', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0087' successfully produced to FedEx [1] at offset 53
# =====================
# {'shipment_id': 'SH0088', 'origin': 'Chennai, IN', 'destination': 'Los Angeles, CA', 'status': 'Shipped', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0088' successfully produced to FedEx [0] at offset 48
# =====================
# {'shipment_id': 'SH0089', 'origin': 'Mumbai, IN', 'destination': 'Portland, OR', 'status': 'In Transit', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0089' successfully produced to FedEx [0] at offset 49
# =====================
# {'shipment_id': 'SH0090', 'origin': 'Kolkata, IN', 'destination': 'Portland, OR', 'status': 'In Transit', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0090' successfully produced to FedEx [1] at offset 54
# =====================
# {'shipment_id': 'SH0091', 'origin': 'Kolkata, IN', 'destination': 'Philadelphia, PA', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0091' successfully produced to FedEx [1] at offset 55
# =====================
# {'shipment_id': 'SH0092', 'origin': 'Kolkata, IN', 'destination': 'Detroit, MI', 'status': 'Delivered', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0092' successfully produced to FedEx [1] at offset 56
# =====================
# {'shipment_id': 'SH0093', 'origin': 'Mumbai, IN', 'destination': 'Phoenix, AZ', 'status': 'In Transit', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0093' successfully produced to FedEx [1] at offset 57
# =====================
# {'shipment_id': 'SH0094', 'origin': 'Mumbai, IN', 'destination': 'Portland, OR', 'status': 'Shipped', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0094' successfully produced to FedEx [0] at offset 50
# =====================
# {'shipment_id': 'SH0095', 'origin': 'Bangalore, IN', 'destination': 'San Antonio, TX', 'status': 'In Transit', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0095' successfully produced to FedEx [0] at offset 51
# =====================
# {'shipment_id': 'SH0096', 'origin': 'Mumbai, IN', 'destination': 'San Antonio, TX', 'status': 'Shipped', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0096' successfully produced to FedEx [0] at offset 52
# =====================
# {'shipment_id': 'SH0097', 'origin': 'Delhi, IN', 'destination': 'Philadelphia, PA', 'status': 'Delivered', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0097' successfully produced to FedEx [0] at offset 53
# =====================
# {'shipment_id': 'SH0098', 'origin': 'Chennai, IN', 'destination': 'Charlotte, NC', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0098' successfully produced to FedEx [1] at offset 58
# =====================
# {'shipment_id': 'SH0099', 'origin': 'Delhi, IN', 'destination': 'San Antonio, TX', 'status': 'Returned', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH0099' successfully produced to FedEx [1] at offset 59
# =====================
# {'shipment_id': 'SH00100', 'origin': 'Kolkata, IN', 'destination': 'San Diego, CA', 'status': 'In Transit', 'timestamp': datetime.datetime(2025, 2, 4, 7, 56, 54, 528040, tzinfo=datetime.timezone.utc)}
# User record b'SH00100' successfully produced to FedEx [0] at offset 54
# =====================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[92], line 19
#      12 producer.produce(
#      13     topic = 'FedEx',
#      14     key = str(data["shipment_id"]),
#      15     value = data,
#      16     on_delivery = delivery_report
#      17 )
#      18 producer.flush()
# ---> 19 time.sleep(2)
#      20 # if i == 10:
#      21 #     break
#
# KeyboardInterrupt:
# %5|1738661382.911|REQTMOUT|rdkafka#producer-4| [thrd:sasl_ssl://b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/5: Timed out MetadataRequest in flight (after 60061ms, timeout #0)
# %4|1738661382.911|REQTMOUT|rdkafka#producer-4| [thrd:sasl_ssl://b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/5: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1738661382.915|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/5: 1 request(s) timed out: disconnect (average rtt 37.464ms) (after 652467ms in state UP)
# %5|1738661383.242|REQTMOUT|rdkafka#producer-4| [thrd:sasl_ssl://pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/bootst]: sasl_ssl://pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/bootstrap: Timed out GetTelemetrySubscriptionsRequest in flight (after 60061ms, timeout #0)
# %4|1738661383.242|REQTMOUT|rdkafka#producer-4| [thrd:sasl_ssl://pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/bootst]: sasl_ssl://pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/bootstrap: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1738661383.243|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/bootst]: sasl_ssl://pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/bootstrap: 1 request(s) timed out: disconnect (average rtt 44.333ms) (after 660146ms in state UP)
# %3|1738661383.920|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/5: Failed to resolve 'b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 4ms in state CONNECT)
# %4|1738661383.920|METADATA|rdkafka#producer-4| [thrd:main]: sasl_ssl://b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/5: Metadata request failed: periodic topic and broker list refresh: Local: Host resolution failure (0ms): Permanent
# %5|1738661443.134|REQTMOUT|rdkafka#producer-4| [thrd:sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1]: sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1: Timed out MetadataRequest in flight (after 60218ms, timeout #0)
# %5|1738661443.134|REQTMOUT|rdkafka#producer-4| [thrd:sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1]: sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1: Timed out MetadataRequest in flight (after 60056ms, timeout #1)
# %4|1738661443.134|REQTMOUT|rdkafka#producer-4| [thrd:sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1]: sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1: Timed out 2 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1738661443.134|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1]: sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1: 2 request(s) timed out: disconnect (average rtt 34.796ms) (after 719022ms in state UP)
# %3|1738661443.140|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b0-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/0: Failed to resolve 'b0-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 5ms in state CONNECT)
# %3|1738661443.247|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1]: sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1: Failed to resolve 'b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 4ms in state CONNECT)
# %4|1738661443.247|METADATA|rdkafka#producer-4| [thrd:main]: sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1: Metadata request failed: broker down: Local: Host resolution failure (0ms): Permanent
# %3|1738661444.092|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b4-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/4: Failed to resolve 'b4-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 4ms in state CONNECT)
# %3|1738661444.252|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1]: sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1: Failed to resolve 'b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 4ms in state CONNECT, 1 identical error(s) suppressed)
# %4|1738661444.252|METADATA|rdkafka#producer-4| [thrd:main]: sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1: Metadata request failed: refresh unavailable topics: Local: Host resolution failure (0ms): Permanent
# %4|1738661444.252|METADATA|rdkafka#producer-4| [thrd:main]: sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1: Metadata request failed: broker down: Local: Host resolution failure (0ms): Permanent
# %4|1738661444.252|METADATA|rdkafka#producer-4| [thrd:main]: sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1: Metadata request failed: refresh unavailable topics: Local: Host resolution failure (0ms): Permanent
# %3|1738661445.092|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b2-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/2]: sasl_ssl://b2-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/2: Failed to resolve 'b2-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 4ms in state CONNECT)
# %3|1738661446.096|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b3-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/3: Failed to resolve 'b3-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 7ms in state CONNECT)
# %3|1738661447.093|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/bootst]: sasl_ssl://pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/bootstrap: Failed to resolve 'pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 4ms in state CONNECT)
# %3|1738661448.094|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/5: Failed to resolve 'b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 5ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1738661449.201|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b3-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/3: Failed to resolve 'b3-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 111ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1738661450.093|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b0-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/0: Failed to resolve 'b0-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 4ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1738661451.094|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b4-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/4: Failed to resolve 'b4-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 4ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1738661452.093|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/bootst]: sasl_ssl://pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/bootstrap: Failed to resolve 'pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 3ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1738661456.095|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b2-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/2]: sasl_ssl://b2-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/2: Failed to resolve 'b2-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 5ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1738661480.101|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b3-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/3: Failed to resolve 'b3-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 6ms in state CONNECT, 3 identical error(s) suppressed)
# %3|1738661481.099|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1]: sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1: Failed to resolve 'b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 4ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1738661482.099|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/5: Failed to resolve 'b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 3ms in state CONNECT, 3 identical error(s) suppressed)
# %3|1738661483.100|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b0-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/0: Failed to resolve 'b0-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 3ms in state CONNECT, 5 identical error(s) suppressed)
# %3|1738661487.102|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b2-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/2]: sasl_ssl://b2-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/2: Failed to resolve 'b2-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 6ms in state CONNECT, 7 identical error(s) suppressed)
# %3|1738661491.100|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/bootst]: sasl_ssl://pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/bootstrap: Failed to resolve 'pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 3ms in state CONNECT, 5 identical error(s) suppressed)
# %3|1738661496.104|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b4-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/4: Failed to resolve 'b4-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 6ms in state CONNECT, 6 identical error(s) suppressed)
# %3|1738661514.105|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b0-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/0: Failed to resolve 'b0-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 5004ms in state CONNECT, 7 identical error(s) suppressed)
# %3|1738661516.106|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b3-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/3: Failed to resolve 'b3-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 4ms in state CONNECT, 3 identical error(s) suppressed)
# %3|1738661520.108|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b2-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/2]: sasl_ssl://b2-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/2: Failed to resolve 'b2-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 5ms in state CONNECT, 6 identical error(s) suppressed)
# %3|1738661522.108|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/bootst]: sasl_ssl://pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/bootstrap: Failed to resolve 'pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 5ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1738661523.108|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/5: Failed to resolve 'b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 5ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1738661524.109|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1]: sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1: Failed to resolve 'b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 5ms in state CONNECT, 5 identical error(s) suppressed)
# %3|1738661533.109|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b4-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/4: Failed to resolve 'b4-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 4ms in state CONNECT, 9 identical error(s) suppressed)
# %3|1738661548.114|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b0-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/0: Failed to resolve 'b0-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 7ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1738661552.113|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b3-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/3: Failed to resolve 'b3-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 5ms in state CONNECT, 5 identical error(s) suppressed)
# %3|1738661556.112|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b2-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/2]: sasl_ssl://b2-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/2: Failed to resolve 'b2-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 3ms in state CONNECT, 5 identical error(s) suppressed)
# %3|1738661557.112|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1]: sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1: Failed to resolve 'b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 3ms in state CONNECT, 2 identical error(s) suppressed)
# %3|1738661558.113|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/bootst]: sasl_ssl://pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/bootstrap: Failed to resolve 'pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 4ms in state CONNECT, 2 identical error(s) suppressed)
# %3|1738661560.113|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/5: Failed to resolve 'b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 3ms in state CONNECT, 10 identical error(s) suppressed)
# %3|1738661564.119|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b4-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/4: Failed to resolve 'b4-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 7ms in state CONNECT, 6 identical error(s) suppressed)
# %3|1738661584.118|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b0-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/0: Failed to resolve 'b0-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 5005ms in state CONNECT, 5 identical error(s) suppressed)
# %3|1738661588.120|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b3-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/3: Failed to resolve 'b3-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 4ms in state CONNECT, 8 identical error(s) suppressed)
# %3|1738661590.121|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/bootst]: sasl_ssl://pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/bootstrap: Failed to resolve 'pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 5ms in state CONNECT, 2 identical error(s) suppressed)
# %3|1738661591.120|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/5: Failed to resolve 'b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 4ms in state CONNECT, 3 identical error(s) suppressed)
# %3|1738661601.122|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b2-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/2]: sasl_ssl://b2-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/2: Failed to resolve 'b2-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 5ms in state CONNECT, 7 identical error(s) suppressed)
# %3|1738661603.122|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1]: sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1: Failed to resolve 'b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 4ms in state CONNECT, 6 identical error(s) suppressed)
# %3|1738661605.122|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b4-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/4: Failed to resolve 'b4-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 4ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1738661618.126|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b0-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/0: Failed to resolve 'b0-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 6ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1738661623.201|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b3-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/3: Failed to resolve 'b3-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 79ms in state CONNECT, 9 identical error(s) suppressed)
# %3|1738661625.127|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/bootst]: sasl_ssl://pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/bootstrap: Failed to resolve 'pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 5ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1738661626.127|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/5: Failed to resolve 'b5-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 6ms in state CONNECT, 5 identical error(s) suppressed)
# %3|1738661633.127|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1]: sasl_ssl://b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/1: Failed to resolve 'b1-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 4ms in state CONNECT, 6 identical error(s) suppressed)
# %3|1738661635.126|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b2-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/2]: sasl_ssl://b2-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/2: Failed to resolve 'b2-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 3ms in state CONNECT, 5 identical error(s) suppressed)
# %3|1738661642.130|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b4-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/4: Failed to resolve 'b4-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 5ms in state CONNECT, 7 identical error(s) suppressed)
# %3|1738661650.130|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b0-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/0: Failed to resolve 'b0-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 4ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1738661654.130|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b3-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/3: Failed to resolve 'b3-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Name or service not known (after 3ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1738661663.132|FAIL|rdkafka#producer-4| [thrd:sasl_ssl://b2-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/2]: sasl_ssl://b2-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092/2: Failed to resolve 'b2-pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092': Temporary failure in name resolution (after 4ms in state CONNECT)
